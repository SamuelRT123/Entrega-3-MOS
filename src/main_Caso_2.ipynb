# %% [markdown]
# #  Calibración y experimentación Caso 2 Proyecto A

# %%
import random

from data_loader import load_instance
from ga_algorithm import GeneticAlgorithm
from verification import export_verification
import time
import pandas as pd

# %%
# SemillaS PARA LAS TRES PRUEBAS
SEED1 = 42
SEED2 = 110
SEED3 = 172

# %%
# PARAMETROS GLOBALES DEL GA 

# Tamaño de población
POP_SIZE = 50

# Número de generaciones
N_GENERATIONS = 200

# Probabilidades de operadores
P_CROSS = 0.8      # probabilidad de cruce
P_MUT = 0.2        # probabilidad de mutación

# %% [markdown]
# ### PRUEBA 1

# %%
resultados1 = []

# %%
# Fijar semilla global (por si hay otros randoms fuera del GA)
random.seed(SEED1)

instance_path = "../data/Proyecto_Caso_2"
config = load_instance(instance_path)


# CONSTRUCCIÓN DEL GA
ga1 = GeneticAlgorithm(
    config=config,
    pop_size=POP_SIZE,
    generations=N_GENERATIONS,
    crossover_rate=P_CROSS,
    mutation_rate=P_MUT,
    seed=SEED1,
)

# EJECUCIÓN
t0 = time.process_time()
best1, history = ga1.evolve()
cpu1 = time.process_time() - t0

print("\nMejor solución encontrada:")
print("Costo:", best1.cost)
print("Factible:", best1.is_feasible)
print("\nParámetros GA usados:")
print(f"  Semilla           : {SEED1}")
print(f"  Población         : {POP_SIZE}")
print(f"  Generaciones      : {N_GENERATIONS}")
print(f"  P(cruce)          : {P_CROSS}")
print(f"  P(mutación)       : {P_MUT}")
print(f"  Tiempo CPU        : {cpu1:.4f} s")

resultados1.append({
    "semilla": SEED1,
    "objetivo": best1.cost,
    "factible": best1.is_feasible,
    "cpu_time": cpu1,
})
# Out:
# Gen 0 | Best Cost: 9392244.87 | Factible: False
# Gen 1 | Best Cost: 7342300.99 | Factible: False
# Gen 2 | Best Cost: 7342300.99 | Factible: False
# Gen 3 | Best Cost: 7342300.99 | Factible: False
# Gen 4 | Best Cost: 7342300.99 | Factible: False
# Gen 5 | Best Cost: 7342300.99 | Factible: False
# Gen 6 | Best Cost: 7342300.99 | Factible: False
# Gen 7 | Best Cost: 7342300.99 | Factible: False
# Gen 8 | Best Cost: 7342300.99 | Factible: False
# Gen 9 | Best Cost: 7342300.99 | Factible: False
# Gen 10 | Best Cost: 7342300.99 | Factible: False
# Gen 11 | Best Cost: 7342300.99 | Factible: False
# Gen 12 | Best Cost: 7342300.99 | Factible: False
# Gen 13 | Best Cost: 7342300.99 | Factible: False
# Gen 14 | Best Cost: 7342300.99 | Factible: False
# Gen 15 | Best Cost: 7342300.99 | Factible: False
# Gen 16 | Best Cost: 7342300.99 | Factible: False
# Gen 17 | Best Cost: 7342300.99 | Factible: False
# Gen 18 | Best Cost: 7342300.99 | Factible: False
# Gen 19 | Best Cost: 7342300.99 | Factible: False
# Gen 20 | Best Cost: 7342300.99 | Factible: False
# Gen 21 | Best Cost: 7342300.99 | Factible: False
# Gen 22 | Best Cost: 7342300.99 | Factible: False
# Gen 23 | Best Cost: 7342300.99 | Factible: False
# Gen 24 | Best Cost: 7342300.99 | Factible: False
# Gen 25 | Best Cost: 7342300.99 | Factible: False
# Gen 192 | Best Cost: 7342300.99 | Factible: False
# Gen 193 | Best Cost: 7342300.99 | Factible: False
# Gen 194 | Best Cost: 7342300.99 | Factible: False
# Gen 195 | Best Cost: 7342300.99 | Factible: False
# Gen 196 | Best Cost: 7342300.99 | Factible: False
# Gen 197 | Best Cost: 7342300.99 | Factible: False
# Gen 198 | Best Cost: 7342300.99 | Factible: False
# Gen 199 | Best Cost: 7342300.99 | Factible: False
#
# Mejor solución encontrada:
# Costo: 7342300.987705481
# Factible: False
#
# Parámetros GA usados:
#   Semilla           : 42
#   Población         : 50
#   Generaciones      : 200
#   P(cruce)          : 0.8
#   P(mutación)       : 0.2
#   Tiempo CPU        : 1.0625 s

# %% [markdown]
# ### PRUEBA 2

# %%
# Fijar semilla global (por si hay otros randoms fuera del GA)
random.seed(SEED2)

instance_path = "../data/Proyecto_Caso_2"
config = load_instance(instance_path)


# CONSTRUCCIÓN DEL GA
ga2 = GeneticAlgorithm(
    config=config,
    pop_size=POP_SIZE,
    generations=N_GENERATIONS,
    crossover_rate=P_CROSS,
    mutation_rate=P_MUT,
    seed=SEED2,
)

# EJECUCIÓN

t0 = time.process_time()
best2, history2 = ga2.evolve()
cpu2 = time.process_time() - t0

print("\nMejor solución encontrada:")
print("Costo:", best2.cost)
print("Factible:", best2.is_feasible)
print("\nParámetros GA usados:")
print(f"  Semilla           : {SEED2}")
print(f"  Población         : {POP_SIZE}")
print(f"  Generaciones      : {N_GENERATIONS}")
print(f"  P(cruce)          : {P_CROSS}")
print(f"  P(mutación)       : {P_MUT}")
print(f"  Tiempo CPU        : {cpu2:.4f} s")

resultados1.append({
    "semilla": SEED2,
    "objetivo": best2.cost,
    "factible": best2.is_feasible,
    "cpu_time": cpu2,
})
# Out:
# Gen 0 | Best Cost: 9278139.98 | Factible: False
# Gen 1 | Best Cost: 7342300.99 | Factible: False
# Gen 2 | Best Cost: 7342300.99 | Factible: False
# Gen 3 | Best Cost: 7342300.99 | Factible: False
# Gen 4 | Best Cost: 7342300.99 | Factible: False
# Gen 5 | Best Cost: 7342300.99 | Factible: False
# Gen 6 | Best Cost: 7342300.99 | Factible: False
# Gen 7 | Best Cost: 7342300.99 | Factible: False
# Gen 8 | Best Cost: 7342300.99 | Factible: False
# Gen 9 | Best Cost: 7342300.99 | Factible: False
# Gen 10 | Best Cost: 7342300.99 | Factible: False
# Gen 11 | Best Cost: 7342300.99 | Factible: False
# Gen 12 | Best Cost: 7342300.99 | Factible: False
# Gen 13 | Best Cost: 7342300.99 | Factible: False
# Gen 14 | Best Cost: 7342300.99 | Factible: False
# Gen 15 | Best Cost: 7342300.99 | Factible: False
# Gen 16 | Best Cost: 7342300.99 | Factible: False
# Gen 17 | Best Cost: 7342300.99 | Factible: False
# Gen 18 | Best Cost: 7342300.99 | Factible: False
# Gen 19 | Best Cost: 7342300.99 | Factible: False
# Gen 20 | Best Cost: 7342300.99 | Factible: False
# Gen 21 | Best Cost: 7342300.99 | Factible: False
# Gen 22 | Best Cost: 7342300.99 | Factible: False
# Gen 23 | Best Cost: 7342300.99 | Factible: False
# Gen 190 | Best Cost: 7342300.99 | Factible: False
# Gen 191 | Best Cost: 7342300.99 | Factible: False
# Gen 192 | Best Cost: 7342300.99 | Factible: False
# Gen 193 | Best Cost: 7342300.99 | Factible: False
# Gen 194 | Best Cost: 7342300.99 | Factible: False
# Gen 195 | Best Cost: 7342300.99 | Factible: False
# Gen 196 | Best Cost: 7342300.99 | Factible: False
# Gen 197 | Best Cost: 7342300.99 | Factible: False
# Gen 198 | Best Cost: 7342300.99 | Factible: False
# Gen 199 | Best Cost: 7342300.99 | Factible: False
#
# Mejor solución encontrada:
# Costo: 7342300.987705481
# Factible: False
#
# Parámetros GA usados:
#   Semilla           : 110
#   Población         : 50
#   Generaciones      : 200
#   P(cruce)          : 0.8
#   P(mutación)       : 0.2
#   Tiempo CPU        : 1.4219 s

# %% [markdown]
# ### PRUEBA 3

# %%
# Fijar semilla global (por si hay otros randoms fuera del GA)
random.seed(SEED3)

instance_path = "../data/Proyecto_Caso_2"
config = load_instance(instance_path)


# CONSTRUCCIÓN DEL GA
ga3 = GeneticAlgorithm(
    config=config,
    pop_size=POP_SIZE,
    generations=N_GENERATIONS,
    crossover_rate=P_CROSS,
    mutation_rate=P_MUT,
    seed=SEED3,
)

# EJECUCIÓN

t0 = time.process_time()
best3, history3 = ga3.evolve()
cpu3 = time.process_time() - t0

print("\nMejor solución encontrada:")
print("Costo:", best3.cost)
print("Factible:", best3.is_feasible)
print("\nParámetros GA usados:")
print(f"  Semilla           : {SEED3}")
print(f"  Población         : {POP_SIZE}")
print(f"  Generaciones      : {N_GENERATIONS}")
print(f"  P(cruce)          : {P_CROSS}")
print(f"  P(mutación)       : {P_MUT}")
print(f"  Tiempo CPU        : {cpu3:.4f} s")

resultados1.append({
    "semilla": SEED3,
    "objetivo": best3.cost,
    "factible": best3.is_feasible,
    "cpu_time": cpu3,
})
# Out:
# Gen 0 | Best Cost: 9353669.81 | Factible: False
# Gen 1 | Best Cost: 7342300.99 | Factible: False
# Gen 2 | Best Cost: 7342300.99 | Factible: False
# Gen 3 | Best Cost: 7342300.99 | Factible: False
# Gen 4 | Best Cost: 7342300.99 | Factible: False
# Gen 5 | Best Cost: 7342300.99 | Factible: False
# Gen 6 | Best Cost: 7342300.99 | Factible: False
# Gen 7 | Best Cost: 7342300.99 | Factible: False
# Gen 8 | Best Cost: 7342300.99 | Factible: False
# Gen 9 | Best Cost: 7342300.99 | Factible: False
# Gen 10 | Best Cost: 7342300.99 | Factible: False
# Gen 11 | Best Cost: 7342300.99 | Factible: False
# Gen 12 | Best Cost: 7342300.99 | Factible: False
# Gen 13 | Best Cost: 7342300.99 | Factible: False
# Gen 14 | Best Cost: 7342300.99 | Factible: False
# Gen 15 | Best Cost: 7342300.99 | Factible: False
# Gen 16 | Best Cost: 7342300.99 | Factible: False
# Gen 17 | Best Cost: 7342300.99 | Factible: False
# Gen 18 | Best Cost: 7342300.99 | Factible: False
# Gen 19 | Best Cost: 7342300.99 | Factible: False
# Gen 20 | Best Cost: 7342300.99 | Factible: False
# Gen 188 | Best Cost: 7342300.99 | Factible: False
# Gen 189 | Best Cost: 7342300.99 | Factible: False
# Gen 190 | Best Cost: 7342300.99 | Factible: False
# Gen 191 | Best Cost: 7342300.99 | Factible: False
# Gen 192 | Best Cost: 7342300.99 | Factible: False
# Gen 193 | Best Cost: 7342300.99 | Factible: False
# Gen 194 | Best Cost: 7342300.99 | Factible: False
# Gen 195 | Best Cost: 7342300.99 | Factible: False
# Gen 196 | Best Cost: 7342300.99 | Factible: False
# Gen 197 | Best Cost: 7342300.99 | Factible: False
# Gen 198 | Best Cost: 7342300.99 | Factible: False
# Gen 199 | Best Cost: 7342300.99 | Factible: False
#
# Mejor solución encontrada:
# Costo: 7342300.987705481
# Factible: False
#
# Parámetros GA usados:
#   Semilla           : 172
#   Población         : 50
#   Generaciones      : 200
#   P(cruce)          : 0.8
#   P(mutación)       : 0.2
#   Tiempo CPU        : 0.9219 s

# %% [markdown]
# ### Resultados

# %%
import matplotlib.pyplot as plt

best_costs1 = history
best_costs2 = history2
best_costs3 = history3

gens1 = range(1, len(best_costs1) + 1)
gens2 = range(1, len(best_costs2) + 1)
gens3 = range(1, len(best_costs3) + 1)

plt.figure(figsize=(8, 5))

plt.plot(gens1, best_costs1, label=f"Semilla {SEED1}")
plt.plot(gens2, best_costs2, label=f"Semilla {SEED2}")
plt.plot(gens3, best_costs3, label=f"Semilla {SEED3}")

plt.xlabel("Generación")
plt.ylabel("Mejor valor de la función objetivo")
plt.title("Convergencia del algoritmo genético – Caso 2")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_corridas = pd.DataFrame(resultados1)
df_corridas
# Out:
#    semilla      objetivo  factible  cpu_time
# 0       42  7.342301e+06     False  1.062500
# 1      110  7.342301e+06     False  1.421875
# 2      172  7.342301e+06     False  0.921875

# %%
stats = pd.DataFrame({
    "estadístico": ["mejor", "peor", "media", "desviación estándar"],
    "objetivo": [
        df_corridas["objetivo"].min(),
        df_corridas["objetivo"].max(),
        df_corridas["objetivo"].mean(),
        df_corridas["objetivo"].std(ddof=1), 
    ],
    "cpu_time": [
        df_corridas["cpu_time"].min(),
        df_corridas["cpu_time"].max(),
        df_corridas["cpu_time"].mean(),
        df_corridas["cpu_time"].std(ddof=1),
    ],
})

stats
# Out:
#            estadístico      objetivo  cpu_time
# 0                mejor  7.342301e+06  0.921875
# 1                 peor  7.342301e+06  1.421875
# 2                media  7.342301e+06  1.135417
# 3  desviación estándar  0.000000e+00  0.257852

# %%
candidatos = [
    {"seed": SEED1, "best": best1},
    {"seed": SEED2, "best": best2},
    {"seed": SEED3, "best": best3},
]

# Primero intentamos quedarnos con la mejor ENTRE LAS FACTIBLES
feasibles = [c for c in candidatos if c["best"].is_feasible]

if feasibles:
    elegido = min(feasibles, key=lambda c: c["best"].cost)
else:
    # Si ninguna fue factible, nos quedamos con la de menor costo (aunque sea infactible)
    elegido = min(candidatos, key=lambda c: c["best"].cost)
    print("No se encontró solución factible; se exporta la de mejor costo (infeasible).")

mejor_sol = elegido["best"]

print("\n>>> Exportando verificación")
print(f"Semilla elegida : {elegido['seed']}")
print(f"Costo           : {mejor_sol.cost}")
print(f"Factible        : {mejor_sol.is_feasible}")

export_verification(
    mejor_sol,
    config,
    "../Archivos_De_Verificacion/verificacion_metaheuristica_GA_A_caso2.csv",
)
# Out:
# No se encontró solución factible; se exporta la de mejor costo (infeasible).
#
# >>> Exportando verificación
# Semilla elegida : 42
# Costo           : 7342300.987705481
# Factible        : False
# Archivo de verificación guardado en: ../Archivos_De_Verificacion/verificacion_metaheuristica_GA_A_caso2.csv

# %%
df = pd.read_csv("../Archivos_De_Verificacion/verificacion_metaheuristica_GA_A_caso2.csv")
df
# Out:
#   VehicleId DepotId  InitialLoad      RouteSequence  ClientsServed  \
# 0      V001     CDA            6       CDA-C004-CDA              1
# 1      V002     CDA           12       CDA-C001-CDA              1
# 2      V003     CDA           12       CDA-C007-CDA              1
# 3      V004     CDA           15       CDA-C002-CDA              1
# 4      V005     CDA           15       CDA-C009-CDA              1
# 5      V006     CDA           10       CDA-C008-CDA              1
# 6      V007     CDA           11       CDA-C006-CDA              1
# 7      V008     CDA           20  CDA-C005-C003-CDA              2
#
#   DemandsSatisfied  TotalDistance  TotalTime      FuelCost      TotalCost
# 0                6      25.030795   0.556240  12884.272359  129688.682936
# 1               12      26.457665   0.587948  13618.734952  134231.303205
# 2               12      30.623997   0.680533  15763.299447  147495.344457
# 3               15      31.587957   0.701955  16259.485072  150564.231687
# 4               15      26.842912   0.596509  13817.035641  135457.784625
# 5               10      21.740977   0.483133  11190.881793  119215.133472
# 6               11      17.427786   0.387284   8970.723549  105483.548061
# 7             5-15      12.040430   0.267565   6197.652799   88332.222035

# %%
import folium
import math

def make_solution_map(config, df_verif):

    depot_code_cfg = str(config.depot.code).strip().upper()
    depot_code_csv = str(df_verif["DepotId"].iloc[0]).strip().upper()


    clients_norm = {}
    for c in config.clients.values():
        key = str(c.code).strip().upper()
        clients_norm[key] = c

    all_lat = [config.depot.lat] + [c.lat for c in config.clients.values()]
    all_lon = [config.depot.lon] + [c.lon for c in config.clients.values()]

    center_lat = sum(all_lat) / len(all_lat)
    center_lon = sum(all_lon) / len(all_lon)

    m = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=12,
        tiles="OpenStreetMap"
    )

    folium.Marker(
        location=[config.depot.lat, config.depot.lon],
        popup=f"Depot {config.depot.code}",
        icon=folium.Icon(color="red", icon="home", prefix="fa")
    ).add_to(m)


    for client in config.clients.values():
        folium.CircleMarker(
            location=[client.lat, client.lon],
            radius=4,
            popup=f"{client.code} - Demanda: {client.demand}",
            color="blue",
            fill=True,
            fill_opacity=0.7,
        ).add_to(m)

    colors = [
        "blue", "green", "purple", "orange", "darkred", "cadetblue",
        "red", "black", "darkblue", "darkpurple"
    ]


    for idx, row in df_verif.iterrows():
        vehicle_id = row["VehicleId"]
        seq = row["RouteSequence"]

        if isinstance(seq, float) and math.isnan(seq):
            continue

        nodes = [s.strip() for s in str(seq).split("-") if s.strip() != ""]

        coords = []
        for code in nodes:
            code_norm = str(code).strip().upper()

            if code_norm in (depot_code_csv, depot_code_cfg):
                n = config.depot
            elif code_norm in clients_norm:
                n = clients_norm[code_norm]


            coords.append((n.lat, n.lon))

        if not coords:
            continue

        col = colors[idx % len(colors)]

        folium.PolyLine(
            coords,
            color=col,
            weight=4,
            opacity=0.8,
            tooltip=f"Vehículo {vehicle_id}"
        ).add_to(m)

    return m

# %%
solution_map = make_solution_map(config, df)
solution_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf725d7195bdecced53a97fc96acf87b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf725d7195bdecced53a97fc96acf87b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf725d7195bdecced53a97fc96acf87b = L.map(
#                 &quot;map_cf725d7195bdecced53a97fc96acf87b&quot;,
#                 {
#                     center: [4.676115107899343, -74.12577042068827],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a88a5430ea46a35313edd7fe81c9aca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a88a5430ea46a35313edd7fe81c9aca.addTo(map_cf725d7195bdecced53a97fc96acf87b);
#
#
#             var marker_db5e594072c66345bda17e23ca4b04db = L.marker(
#                 [4.743359, -74.153536],
#                 {
# }
#             ).addTo(map_cf725d7195bdecced53a97fc96acf87b);
#
#
#             var icon_601f3817edb12c743b90bc93f7114103 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f9ca0ddf2d09ff5e5e5ba04738204c75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6577eabdd7accc4e7df947348bbd849 = $(`&lt;div id=&quot;html_d6577eabdd7accc4e7df947348bbd849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Depot cd01&lt;/div&gt;`)[0];
#                 popup_f9ca0ddf2d09ff5e5e5ba04738204c75.setContent(html_d6577eabdd7accc4e7df947348bbd849);
#
#
#
#         marker_db5e594072c66345bda17e23ca4b04db.bindPopup(popup_f9ca0ddf2d09ff5e5e5ba04738204c75)
#         ;
#
#
#
#
#                 marker_db5e594072c66345bda17e23ca4b04db.setIcon(icon_601f3817edb12c743b90bc93f7114103);
#
#
#             var circle_marker_024663fde524874613ea731cf9d7d755 = L.circleMarker(
#                 [4.632552840424734, -74.19699184741948],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf725d7195bdecced53a97fc96acf87b);
#
#
#         var popup_1a1497ea7613e9b314287fb2652e8970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e18c37f8bc3f1b9e7e5343b6d1736774 = $(`&lt;div id=&quot;html_e18c37f8bc3f1b9e7e5343b6d1736774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;c001 - Demanda: 12.0&lt;/div&gt;`)[0];
#                 popup_1a1497ea7613e9b314287fb2652e8970.setContent(html_e18c37f8bc3f1b9e7e5343b6d1736774);
#
#
#
#         circle_marker_024663fde524874613ea731cf9d7d755.bindPopup(popup_1a1497ea7613e9b314287fb2652e8970)
#         ;
#
#
#
#
#             var circle_marker_4b96078b75f7d96732236d4987af2ba9 = L.circleMarker(
#                 [4.601328214582278, -74.15503659129905],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf725d7195bdecced53a97fc96acf87b);
#
#
#         var popup_1a75df3b82ac3289a12f693208a9c4d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a08aec1ff5ea334cf00737de57d72597 = $(`&lt;div id=&quot;html_a08aec1ff5ea334cf00737de57d72597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;c002 - Demanda: 15.0&lt;/div&gt;`)[0];
#                 popup_1a75df3b82ac3289a12f693208a9c4d6.setContent(html_a08aec1ff5ea334cf00737de57d72597);
#
#
#
#         circle_marker_4b96078b75f7d96732236d4987af2ba9.bindPopup(popup_1a75df3b82ac3289a12f693208a9c4d6)
#         ;
#
#
#
#
#             var c

# %%
solution_map.save("../Archivos_De_Verificacion/mapa_caso2.html")
